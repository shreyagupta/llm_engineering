# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# I will use Gradio for this!

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
# !python price_is_right_final.py
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-10-09 21:51:02 -0700] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# ...

# %% [markdown]
# # What the UI looks like!
#
# ### I added the 3D plot just for fun!

# %%
from IPython.display import Image, display

# %%
display(Image(filename="/Users/shreyagupta/projects/deep-llm-engineering/images/price_is_right_final_ui.png"))

# %% [markdown]
# ### Notifcations sent by agent and corresponding link

# %% [markdown]
# #### In this example the agent's estmate of the actual price is within \$7 of the actual price!

# %%
display(Image(filename="/Users/shreyagupta/projects/deep-llm-engineering/images/price_is_right_final_example.png"))
