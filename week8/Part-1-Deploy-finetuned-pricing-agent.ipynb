# %% [markdown]
# # Creating an agent that can predict the price based on item description

# %% [markdown]
# ## 1) Deploy Pricing model using Modal
#
# We deploy the pricing model using Modal. The pricing model is in the file `pricer_service2.py`. It is constructed in an optimized way so that the model only needs to be loaded once and can be used for many instances. This will help get quicker predictions for multiple item descriptions at inferece.

# %%
import modal

# %%
# !modal deploy -m pricer_service2
# Out:
# ⠸ Creating objects.....
# └── ⠋ Creating mount
#     /Users/shreyagupta/projects/llm_engineering/week8/pricer_service2.py:
# Building image im-EDojfuFlVQ6fDuxHx8KFD1
# ⠦ Creating objects...
# ⠦ Creating objects...ers/shreyagupta/projects/llm_engineering/week8/pricer_se
# └── 🔨 Created mount
# agupta/projects/llm_engineering/week8/pricer_service2.py
# => Step 0: FROM base
# ⠇ Creating objects...
# 🔨 Created mount /Users/shreyagupta/projects/llm_engineering/week8/pricer_se
# => Step 1: RUN python -m pip install accelerate bitsandbytes huggingface peft torch transformers
# ⠇ Creating objects...
# ⠏ Creating objects...ers/shreyagupta/projects/llm_engineering/week8/pricer_se
# └── 🔨 Created mount
# ⠹ Creating objects...eering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠴ Creating objects...eering/week8/pricer_service2.py
# └── 🔨 Created mount
# ⠏ Creating objects...eering/week8/pricer_service2.py
# └── 🔨 Created mount
# Looking in indexes: http://pypi-mirror.modal.local:5555/simple
# ...

# %%
Pricer = modal.Cls.from_name("pricer-service", "Pricer")
pricer = Pricer()
reply = pricer.price.remote("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
print(reply)
# Out:
# 133.0

# %% [markdown]
# ## 2) An Agent class is created and added.
#
# ### This will be the class where all the agents will be defined.
#
# Here we call the `SpecialistAgent` that we have created to predict price of an item using our "pricer_service" that in turn uses the pricing model that we created by finetuning llama-3.1 using 400K training samples!

# %%
from agents.specialist_agent import SpecialistAgent

# %%
agent = SpecialistAgent()
agent.price("Quadcast HyperX condenser mic, connects via usb-c to your computer for crystal clear audio")
# Out:
# 133.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 2nd generation")
# Out:
# 299.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 16 pro max")
# Out:
# 799.0

# %%
agent = SpecialistAgent()
agent.price("iPad Pro 17 pro max")
# Out:
# 799.0

# %% [markdown]
# # Now onto cretaing RAG in Part 2!
